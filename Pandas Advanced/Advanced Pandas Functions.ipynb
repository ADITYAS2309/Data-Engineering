# %% [markdown]
# # Pandas Advanced Functions

# %%
import pandas as pd
import numpy as np
import datetime as dt
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('Auto Sales data.csv')

# %%
df.head(3)
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
#
#     ORDERDATE  DAYS_SINCE_LASTORDER   STATUS  PRODUCTLINE  MSRP PRODUCTCODE  \
# 0  24/02/2018                   828  Shipped  Motorcycles    95    S10_1678
# 1  07/05/2018                   757  Shipped  Motorcycles    95    S10_1678
# 2  01/07/2018                   703  Shipped  Motorcycles    95    S10_1678
#
#          CUSTOMERNAME             PHONE                   ADDRESSLINE1   CITY  \
# 0   Land of Toys Inc.        2125557818        897 Long Airport Avenue    NYC
# 1  Reims Collectables        26.47.1555             59 rue de l'Abbaye  Reims
# 2     Lyon Souveniers  +33 1 46 62 7555  27 rue du Colonel Pierre Avia  Paris
#
#   POSTALCODE COUNTRY CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE
# 0      10022     USA              Yu             Kwai    Small
# 1      51100  France         Henriot             Paul    Small
# 2      75508  France        Da Cunha           Daniel   Medium

# %%
df = df[['QUANTITYORDERED', 'PRICEEACH', 'SALES', 'ORDERDATE', 'DAYS_SINCE_LASTORDER', 'STATUS',
        'PRODUCTLINE', 'MSRP', 'CITY', 'COUNTRY', 'DEALSIZE']]

# %%
df.head(3)
# Out:
#    QUANTITYORDERED  PRICEEACH    SALES   ORDERDATE  DAYS_SINCE_LASTORDER  \
# 0               30      95.70  2871.00  24/02/2018                   828
# 1               34      81.35  2765.90  07/05/2018                   757
# 2               41      94.74  3884.34  01/07/2018                   703
#
#     STATUS  PRODUCTLINE  MSRP   CITY COUNTRY DEALSIZE
# 0  Shipped  Motorcycles    95    NYC     USA    Small
# 1  Shipped  Motorcycles    95  Reims  France    Small
# 2  Shipped  Motorcycles    95  Paris  France   Medium

# %%
df.shape
# Out:
# (2747, 11)

# %% [markdown]
# ### Data type of each column

# %%
df.dtypes
# Out:
# QUANTITYORDERED           int64
# PRICEEACH               float64
# SALES                   float64
# ORDERDATE                object
# DAYS_SINCE_LASTORDER      int64
# STATUS                   object
# PRODUCTLINE              object
# MSRP                      int64
# CITY                     object
# COUNTRY                  object
# DEALSIZE                 object
# dtype: object

# %% [markdown]
# ### Count of Nulls

# %%
df.isnull().sum()
# Out:
# QUANTITYORDERED         0
# PRICEEACH               0
# SALES                   0
# ORDERDATE               0
# DAYS_SINCE_LASTORDER    0
# STATUS                  0
# PRODUCTLINE             0
# MSRP                    0
# CITY                    0
# COUNTRY                 0
# DEALSIZE                0
# dtype: int64

# %% [markdown]
# ### Unique values in a column

# %%
df.COUNTRY.unique()
# Out:
# array(['USA', 'France', 'Norway', 'Australia', 'Finland', 'Austria', 'UK',
#        'Spain', 'Sweden', 'Singapore', 'Canada', 'Japan', 'Italy',
#        'Denmark', 'Belgium', 'Philippines', 'Germany', 'Switzerland',
#        'Ireland'], dtype=object)

# %% [markdown]
# ### Number of unique values in a column

# %%
df.COUNTRY.nunique()
# Out:
# 19

# %% [markdown]
# ### Check for duplicates

# %% [markdown]
# subset: by default will remove duplicate rows, else only those from specified column
#
# keep: Values to keep and other duplicates will be removed in the order they occur in dataset

# %%
df.drop_duplicates(subset = ['PRODUCTLINE'],)
# Out:
#       QUANTITYORDERED  PRICEEACH    SALES   ORDERDATE  DAYS_SINCE_LASTORDER  \
# 0                  30      95.70  2871.00  24/02/2018                   828
# 24                 26     207.87  5404.62  29/01/2018                   878
# 200                27     125.74  3394.98  29/01/2018                  1054
# 454                39     123.29  4808.31  10/01/2018                  1327
# 526                36     146.65  5279.40  17/02/2018                  1361
# 897                41      83.44  3421.04  17/02/2018                  1732
# 1023               38     113.95  4330.10  11/02/2018                  1864
#
#        STATUS       PRODUCTLINE  MSRP       CITY  COUNTRY DEALSIZE
# 0     Shipped       Motorcycles    95        NYC      USA    Small
# 24    Shipped      Classic Cars   214    Stavern   Norway   Medium
# 200   Shipped  Trucks and Buses   136    Stavern   Norway   Medium
# 454   Shipped      Vintage Cars   102        NYC      USA   Medium
# 526   Shipped            Planes   157    Bergamo    Italy   Medium
# 897   Shipped             Ships    86    Bergamo    Italy   Medium
# 1023  Shipped            Trains   100  Kobenhavn  Denmark   Medium

# %% [markdown]
# ### Boolean list of duplicated rows for filtering purposes

# %%
df.duplicated(subset = ['PRODUCTLINE'])
# Out:
# 0       False
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 2742     True
# 2743     True
# 2744     True
# 2745     True
# 2746     True
# Length: 2747, dtype: bool

# %%
### Change dtypes

# %% [markdown]
# ### Pandas Data Time

# %%
pd.DataFrame({'dates': [dt.datetime.now()]})
# Out:
#                        dates
# 0 2026-01-11 18:32:07.475957

# %%
df.ORDERDATE.dtype
# Out:
# dtype('O')

# %%
df = df.assign(date_pd = pd.to_datetime(df.ORDERDATE, ))
df.dtypes
# Out:
# QUANTITYORDERED                  int64
# PRICEEACH                      float64
# SALES                          float64
# ORDERDATE                       object
# DAYS_SINCE_LASTORDER             int64
# STATUS                          object
# PRODUCTLINE                     object
# MSRP                             int64
# CITY                            object
# COUNTRY                         object
# DEALSIZE                        object
# date_pd                 datetime64[ns]
# dtype: object

# %%
# STRPTIME: Converts str to datetime datatype
# STRFTIME: Converts datatime to str datatype
df['date_dt'] = df['ORDERDATE'].apply(lambda x: dt.datetime.strptime(x, '%d/%m/%Y'))
df.dtypes
# Out:
# QUANTITYORDERED                  int64
# PRICEEACH                      float64
# SALES                          float64
# ORDERDATE                       object
# DAYS_SINCE_LASTORDER             int64
# STATUS                          object
# PRODUCTLINE                     object
# MSRP                             int64
# CITY                            object
# COUNTRY                         object
# DEALSIZE                        object
# date_pd                 datetime64[ns]
# date_dt                 datetime64[ns]
# dtype: object

# %%
df.head(1)
# Out:
#    QUANTITYORDERED  PRICEEACH   SALES   ORDERDATE  DAYS_SINCE_LASTORDER  \
# 0               30       95.7  2871.0  24/02/2018                   828
#
#     STATUS  PRODUCTLINE  MSRP CITY COUNTRY DEALSIZE    date_pd    date_dt
# 0  Shipped  Motorcycles    95  NYC     USA    Small 2018-02-24 2018-02-24

# %% [markdown]
# ### More Date time

# %%
d = pd.DataFrame({'date': [dt.datetime.now()]})
d['date2'] = d['date'].dt.strftime("%Y-%m-%d %H:%M:%S")
d['date3'] = d['date'].astype(str)
d['date4'] = dt.datetime(2025,1,1)
d
# Out:
#                         date                date2                       date3  \
# 0 2026-01-11 18:32:07.649399  2026-01-11 18:32:07  2026-01-11 18:32:07.649399
#
#        date4
# 0 2025-01-01

# %%
d.dtypes
# Out:
# date     datetime64[ns]
# date2            object
# date3            object
# date4    datetime64[us]
# dtype: object

# %%
dt.datetime.strptime(d.date2[0], "%Y-%m-%d %H:%M:%S")
# Out:
# datetime.datetime(2026, 1, 11, 18, 32, 7)

# %%
d.date - d.date4
# Out:
# 0   375 days 18:32:07.649399
# dtype: timedelta64[ns]

# %%
d.date.dt.day, d.date.dt.hour
# Out:
# (0    11
#  Name: date, dtype: int32,
#  0    18
#  Name: date, dtype: int32)

# %%
import pytz
# Define timezone
tz = pytz.timezone('Etc/GMT+6')
current_time = datetime.now(tz)
current_time
# Out:
# datetime.datetime(2026, 1, 11, 7, 2, 7, 744514, tzinfo=<StaticTzInfo 'Etc/GMT+6'>)

# %%
pd.DataFrame({'date tz': [current_time]})
# Out:
#                            date tz
# 0 2026-01-11 07:02:07.744514-06:00

# %% [markdown]
# ### Group by

# %%
df[['DEALSIZE', 'SALES', 'STATUS']].groupby(by = ['DEALSIZE', 'STATUS'], as_index = False).count()
# Out:
#    DEALSIZE      STATUS  SALES
# 0     Large    Disputed      5
# 1     Large  In Process      3
# 2     Large     On Hold      5
# 3     Large    Resolved      1
# 4     Large     Shipped    138
# 5    Medium   Cancelled     33
# 6    Medium    Disputed      5
# 7    Medium  In Process     18
# 8    Medium     On Hold     24
# 9    Medium    Resolved     26
# 10   Medium     Shipped   1243
# 11    Small   Cancelled     27
# 12    Small    Disputed      4
# 13    Small  In Process     20
# 14    Small     On Hold     15
# 15    Small    Resolved     20
# 16    Small     Shipped   1160

# %% [markdown]
# ### Aggregate and Group by

# %%
agg = df[['DEALSIZE', 'SALES', 'STATUS', 'QUANTITYORDERED']].groupby(by = ['DEALSIZE', 'STATUS'], as_index = False).agg(
                                                                                               MeanSales = ('SALES', 'mean'),
                                                                                               CountSales = ('SALES', 'count'),
                                                                                               SumOrders = ('QUANTITYORDERED','sum'))
agg
# Out:
#    DEALSIZE      STATUS    MeanSales  CountSales  SumOrders
# 0     Large    Disputed  8549.422000           5        296
# 1     Large  In Process  9050.786667           3        153
# 2     Large     On Hold  8588.138000           5        373
# 3     Large    Resolved  8884.800000           1         45
# 4     Large     Shipped  8240.807536         138       6327
# 5    Medium   Cancelled  4168.948788          33       1247
# 6    Medium    Disputed  4432.966000           5        184
# 7    Medium  In Process  4654.825000          18        762
# 8    Medium     On Hold  4430.909583          24       1097
# 9    Medium    Resolved  3998.726923          26       1010
# 10   Medium     Shipped  4406.593524        1243      46909
# 11    Small   Cancelled  2107.858148          27        791
# 12    Small    Disputed  1825.230000           4        117
# 13    Small  In Process  1689.537500          20        575
# 14    Small     On Hold  1979.778000          15        409
# 15    Small    Resolved  1893.329000          20        605
# 16    Small     Shipped  2072.816164        1160      35528

# %% [markdown]
# ### Pivot

# %%
# Works when there is unique value for each index and column
pvt  = agg.pivot(index = 'DEALSIZE', columns = 'STATUS', values = 'MeanSales',)
pvt
# Out:
# STATUS      Cancelled  Disputed   In Process      On Hold     Resolved  \
# DEALSIZE
# Large             NaN  8549.422  9050.786667  8588.138000  8884.800000
# Medium    4168.948788  4432.966  4654.825000  4430.909583  3998.726923
# Small     2107.858148  1825.230  1689.537500  1979.778000  1893.329000
#
# STATUS        Shipped
# DEALSIZE
# Large     8240.807536
# Medium    4406.593524
# Small     2072.816164

# %% [markdown]
# ### Pivot Table

# %%
pvtb = df.pivot_table(index = 'DEALSIZE', columns = 'STATUS', values = 'SALES', aggfunc = 'mean')
pvtb
# Out:
# STATUS      Cancelled  Disputed   In Process      On Hold     Resolved  \
# DEALSIZE
# Large             NaN  8549.422  9050.786667  8588.138000  8884.800000
# Medium    4168.948788  4432.966  4654.825000  4430.909583  3998.726923
# Small     2107.858148  1825.230  1689.537500  1979.778000  1893.329000
#
# STATUS        Shipped
# DEALSIZE
# Large     8240.807536
# Medium    4406.593524
# Small     2072.816164

# %% [markdown]
# ### Value Counts, Sort Values, map & np.where Function

# %%
df['Price Category'] = np.where(df.PRICEEACH < 100, 'Less than 100',
                                np.where(df.PRICEEACH > 200, 'More than 200',
                               'Between 100 and 200')
                               )

# %%
df['Price Category'].value_counts()
# Out:
# Price Category
# Less than 100          1479
# Between 100 and 200    1212
# More than 200            56
# Name: count, dtype: int64

# %%
maps = {"Less than 100": 1, 
        'Between 100 and 200':2,
        'More than 200':3 }
df['Mapped Column'] = df['Price Category'].map(maps)

# %%
df.head(3)
# Out:
#    QUANTITYORDERED  PRICEEACH    SALES   ORDERDATE  DAYS_SINCE_LASTORDER  \
# 0               30      95.70  2871.00  24/02/2018                   828
# 1               34      81.35  2765.90  07/05/2018                   757
# 2               41      94.74  3884.34  01/07/2018                   703
#
#     STATUS  PRODUCTLINE  MSRP   CITY COUNTRY DEALSIZE    date_pd    date_dt  \
# 0  Shipped  Motorcycles    95    NYC     USA    Small 2018-02-24 2018-02-24
# 1  Shipped  Motorcycles    95  Reims  France    Small 2018-05-07 2018-05-07
# 2  Shipped  Motorcycles    95  Paris  France   Medium 2018-07-01 2018-07-01
#
#   Price Category  Mapped Column
# 0  Less than 100              1
# 1  Less than 100              1
# 2  Less than 100              1

# %%
df['Mapped Column'].value_counts()
# Out:
# Mapped Column
# 1    1479
# 2    1212
# 3      56
# Name: count, dtype: int64

# %%
df.sort_values(by = ['QUANTITYORDERED', 'PRICEEACH'], ascending = [False, True])
# Out:
#       QUANTITYORDERED  PRICEEACH     SALES   ORDERDATE  DAYS_SINCE_LASTORDER  \
# 399                97      93.28   9048.16  14/04/2020                   447
# 2511               85      88.75   7543.75  03/04/2020                  2570
# 2614               77      92.00   7084.00  03/04/2020                  2673
# 1656               76      94.50   7182.00  22/04/2020                  1696
# 1930               76     154.47  11739.70  14/04/2020                  1978
# ...               ...        ...       ...         ...                   ...
# 2434               11     103.21   1135.31  03/04/2020                  2493
# 871                10      88.14    881.40  30/05/2020                   873
# 298                10     109.22   1092.20  17/05/2020                   313
# 1238                6      90.19    541.14  22/04/2020                  1278
# 721                 6     130.94    785.64  23/04/2020                   760
#
#           STATUS   PRODUCTLINE  MSRP        CITY    COUNTRY DEALSIZE  \
# 399      Shipped  Classic Cars   115  Strasbourg     France    Large
# 2511     On Hold        Planes    99      Newark        USA    Large
# 2614     On Hold        Planes    80      Newark        USA    Large
# 1656     On Hold  Classic Cars    90    San Jose        USA    Large
# 1930     Shipped  Classic Cars   140  Strasbourg     France    Large
# ...          ...           ...   ...         ...        ...      ...
# 2434     On Hold        Planes    91      Newark        USA    Small
# 871   In Process  Vintage Cars   101   Bruxelles    Belgium    Small
# 298      Shipped  Classic Cars   117    Salzburg    Austria    Small
# 1238     On Hold  Vintage Cars    92    San Jose        USA    Small
# 721      Shipped  Vintage Cars   127   Singapore  Singapore    Small
#
#         date_pd    date_dt       Price Category  Mapped Column
# 399  2020-04-14 2020-04-14        Less than 100              1
# 2511 2020-04-03 2020-04-03        Less than 100              1
# 2614 2020-04-03 2020-04-03        Less than 100              1
# 1656 2020-04-22 2020-04-22        Less than 100              1
# 1930 2020-04-14 2020-04-14  Between 100 and 200              2
# ...         ...        ...                  ...            ...
# 2434 2020-04-03 2020-04-03  Between 100 and 200              2
# 871  2020-05-30 2020-05-30        Less than 100              1
# 298  2020-05-17 2020-05-17  Between 100 and 200              2
# 1238 2020-04-22 2020-04-22        Less than 100              1
# 721  2020-04-23 2020-04-23  Between 100 and 200              2
#
# [2747 rows x 15 columns]

# %% [markdown]
# ### str with isin/contains

# %%
df.STATUS.value_counts()
# Out:
# STATUS
# Shipped       2541
# Cancelled       60
# Resolved        47
# On Hold         44
# In Process      41
# Disputed        14
# Name: count, dtype: int64

# %%
df[df.STATUS.str.contains('Hold',)].shape
# Out:
# (44, 15)

# %%
df[df.STATUS.isin(['On Hold', 'Resolved'])].shape
# Out:
# (91, 15)

# %% [markdown]
# ## Join/Merge & Concat

# %%
df1 = pd.DataFrame(df.DEALSIZE.unique(), columns = ['dealsize'])
df1['deal_id'] = np.arange(1,4)

df_merged = pd.merge(df[['DEALSIZE', 'QUANTITYORDERED']], df1, left_on = 'DEALSIZE', right_on = 'dealsize', how = 'inner')
df_merged.head()
# Out:
#   DEALSIZE  QUANTITYORDERED dealsize  deal_id
# 0    Small               30    Small        1
# 1    Small               34    Small        1
# 2   Medium               41   Medium        2
# 3   Medium               45   Medium        2
# 4   Medium               36   Medium        2

# %%
df_concat = pd.concat([df1, df1], axis = 0)
df_concat
# Out:
#   dealsize  deal_id
# 0    Small        1
# 1   Medium        2
# 2    Large        3
# 0    Small        1
# 1   Medium        2
# 2    Large        3

# %% [markdown]
# ## any and all

# %%
df1 = df[['QUANTITYORDERED', 'MSRP']]
print('Initial Shape', df1.shape[0])

print('Sum True with all:', sum((df1[['QUANTITYORDERED', 'MSRP']]>45).all(axis = 1)))

print('Sum True with any:', sum((df1[['QUANTITYORDERED', 'MSRP']]>45).any(axis = 1)))
# Out:
# Initial Shape 2747
# Sum True with all: 439
# Sum True with any: 2598
